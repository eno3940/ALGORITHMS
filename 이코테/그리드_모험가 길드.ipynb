# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #아이디어
# #가장 작은 숫자부터 그룹을 만드는게 가장 best

# %%
N=int(input())
data = list(map(int, input().split()))
# Out:
# 5
# 2 3 1 2 2

# %%
data=sorted(data)

# %%
data
# Out:
# [1, 2, 2, 2, 3]

# %%
cnt=0
result=0
for i in data:
    cnt+=1
    if cnt>=i:
        result+=1
        cnt=0

# %%
result
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
strings=input()
# Out:
# 567

# %%
answer =int(strings[0])
for s in range(1,len(strings)):
    if int(strings[s])<=1 or answer<=1:
        answer+=int(strings[s])
    else:
        answer*=int(strings[s])

# %%
answer
# Out:
# 210

# %%
strings
# Out:
# '02984'

# %% [markdown]
# ![image.png](attachment:image.png)
